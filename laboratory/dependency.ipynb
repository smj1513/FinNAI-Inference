# %%
# %pip install uv

# %%
# !uv pip install --system -U langchain>=1.0.0 langchain-core>=1.0.0 langchain-community>=1.0.0 langgraph>=1.0.0 langchain-openai>=1.0.0 langchain-postgres langchain-text-splitters langchain-upstage langchain-mcp-adapters langchain-teddynote
# Out:
# Using Python 3.11.9 environment at: C:\Python311
# Resolved 135 packages in 839ms
# Prepared 100 packages in 32ms
# Uninstalled 6 packages in 769ms
# Installed 100 packages in 2.58s
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.2
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anthropic==0.74.0
#  + asyncpg==0.30.0
#  + backports-tarfile==1.2.0
#  + certifi==2025.11.12
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + cryptography==46.0.3
#  + dataclasses-json==0.6.7
#  + deepl==1.25.0
#  + distro==1.9.0
#  + docstring-parser==0.17.0
#  + docutils==0.22.3
#  + feedparser==6.0.12
#  - filelock==3.12.2
#  + filelock==3.20.0
#  + frozenlist==1.8.0
#  + fsspec==2025.10.0
#  + greenlet==3.2.4
#  + httpx-sse==0.4.3
#  + huggingface-hub==0.36.0
#  + id==1.5.0
#  - idna==3.7
#  + idna==3.11
#  - importlib-metadata==8.5.0
#  + importlib-metadata==8.7.0
#  + jaraco-context==6.0.1
#  + jaraco-functools==4.3.0
#  + jiter==0.12.0
#  + joblib==1.5.2
#  + jpype1==1.6.0
# ...

# %%
# 만약 의존성 추가된거 있으면 requirements.txt 업데이트 하기
import pkg_resources
# !pip-chill > ../requirements.txt
# Out:
# E:\pythonProject\FinNAI-Inference\.venv\Lib\site-packages\pip_chill\pip_chill.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
#%pip install -r requirements.txt
